# %% [markdown]
# # List
#
# Case Study: Managing Product Inventory
#
# You are tasked with developing a program to manage the inventory of a store using Python lists. Each product in the inventory is represented by a list containing the product name, price, and quantity.

# %% [markdown]
# Create a list of lists (inventory) to store product information.

# %%
#answer here

# %% [markdown]
#  Add a new product to the inventory.

# %%
#answer here

# %% [markdown]
#  Update the quantity of a specific product.

# %%
#answer here

# %% [markdown]
#  Calculate the total value of the inventory (sum of prices multiplied by quantities).

# %%
#answer here

# %% [markdown]
#  Remove a product from the inventory based on user input.

# %% [markdown]
# # Tuple
#
# Case Study: Exam Score Analysis
#
# You are analyzing the scores of students in an exam using Python tuples. Each tuple contains the student's name and their scores in different subjects.

# %% [markdown]
# Create tuples for several students with their names and exam scores.

# %%
#answer here

# %% [markdown]
# Find the student with the highest total score.

# %%
#answer here

# %% [markdown]
# Calculate the average score in a specific subject across all students.

# %%
#answer here

# %% [markdown]
# Sort students based on their total scores.

# %%
#answer here

# %% [markdown]
# Identify students who scored below a certain value in any subject.

# %%
#answer here

# %% [markdown]
# # Dictionary
#
# Case Study: Online Library Management
#
# You are developing a system to manage books in an online library using Python dictionaries. Each book is represented by a dictionary with keys such as title, author, genre, and availability status.

# %%
#answer here

# %% [markdown]
# Create dictionaries for several books with different attributes.

# %%
#answer here

# %% [markdown]
# Add a new book to the library.

# %%
#answer here

# %% [markdown]
# Update the availability status of a specific book.

# %%
#answer here

# %% [markdown]
# Search for books by a specific author or genre.

# %%
#answer here

# %% [markdown]
# Remove a book from the library based on user input.

# %%
#answer here

# %% [markdown]
# # Set
#
# Case Study: Social Media Analytics
#
# You are analyzing user interactions on a social media platform using Python sets. Each set represents the followers of a specific user.

# %% [markdown]
# Create sets of followers for several users.

# %%
#answer here

# %% [markdown]
# Find common followers between two users.

# %%
#answer here

# %% [markdown]
# Identify users who have unique followers compared to others.

# %%
#answer here

# %% [markdown]
# Calculate the total number of unique followers across all users.

# %%
#answer here

# %% [markdown]
# Determine if a specific user is following another user.

# %%
#answer here
